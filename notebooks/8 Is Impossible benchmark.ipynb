# %%
import pandas as pd

import os

os.chdir("../scripts")

from data_processing import processing, poquad
from t5 import load_t5 as t5

# %%
train_df, valid_df = poquad.load_poquad_manually_downloaded("../data/poquad-manually-processed/")

# %%
train_input = poquad.dataset_into_str_input(train_df)

# %%
valid_input = poquad.dataset_into_str_input(valid_df)

# %%
tokenizer, model = t5.load_plt5("../models/plt5-small-2epochs")

# %%
valid_input[valid_df["is_impossible"].reset_index(drop=True)]
# Out:
#                                              input_text  \
# 4     kontekst: Miszna  Pisma rabiniczne – w tym Mis...
# 7     kontekst: Emilia Plater  Sformowany przez nią ...
# 9     kontekst: Emilia Plater  Sformowany przez nią ...
# 12    kontekst: Peter Phillips  Zaręczyny pary ogłos...
# 19    kontekst: Karnawał  Dawniej w zapusty jedzono ...
# ...                                                 ...
# 7042  kontekst: Michał Czernecki  Od 2013 za dyrekcj...
# 7044  kontekst: Michał Czernecki  Od 2013 za dyrekcj...
# 7049  kontekst: Gimnazjum im. Adama Mickiewicza w Pr...
# 7050  kontekst: Świnoujście  Polską część wyspy Uzna...
# 7058  kontekst: Bundeswehra  Reforma sił zbrojnych N...
#
#                        target_text
# 4     odpowiedź: [BRAK_ODPOWIEDZI]
# 7     odpowiedź: [BRAK_ODPOWIEDZI]
# 9     odpowiedź: [BRAK_ODPOWIEDZI]
# 12    odpowiedź: [BRAK_ODPOWIEDZI]
# 19    odpowiedź: [BRAK_ODPOWIEDZI]
# ...                            ...
# 7042  odpowiedź: [BRAK_ODPOWIEDZI]
# 7044  odpowiedź: [BRAK_ODPOWIEDZI]
# 7049  odpowiedź: [BRAK_ODPOWIEDZI]
# 7050  odpowiedź: [BRAK_ODPOWIEDZI]
# 7058  odpowiedź: [BRAK_ODPOWIEDZI]
#
# [1296 rows x 2 columns]
