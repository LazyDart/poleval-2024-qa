# %%
import pandas as pd
from Levenshtein import distance

import os
import re

os.chdir("../scripts")

from data_processing import poquad, processing
from t5 import load_t5

# %%
train_df, valid_df = poquad.load_poquad_manually_downloaded("../data/poquad-manually-processed")

# %%
train_input = poquad.dataset_into_str_input(train_df)
valid_input = poquad.dataset_into_str_input(valid_df)

# %%
tokenizer_og, model_og = load_t5.load_plt5("../models/plt5-original-small")
tokenizer, model = load_t5.load_plt5("../models/plt5-small-8epochs")

# %%
sample = valid_input[valid_input["target_text"] == "odpowiedź: [BRAK_ODPOWIEDZI]"].sample(100)#.iloc[7058:7059]
# sample = train_input.iloc[0:1]

distances = []


for i in range(100):
    output_og = tokenizer_og(sample["input_text"].iloc[i], return_tensors="pt").input_ids
    output = tokenizer(sample["input_text"].iloc[i], return_tensors="pt").input_ids

    gen_og = model_og.generate(output_og, max_length=128, num_beams=4, num_return_sequences=1, no_repeat_ngram_size=2, early_stopping=True)
    gen = model.generate(output, max_length=128, num_beams=4, num_return_sequences=1, no_repeat_ngram_size=2, early_stopping=True)

    gen_og_str = tokenizer_og.batch_decode(gen_og, skip_special_tokens=True)
    gen_str = tokenizer.batch_decode(gen, skip_special_tokens=True)

    dist_og = distance(sample["target_text"].iloc[i], gen_og_str[0])
    dist = distance(sample["target_text"].iloc[i], gen_str[0])

    distances.append((dist_og, dist, sample["input_text"].iloc[i], sample["target_text"].iloc[i], gen_og_str[0], gen_str[0]))

# %%
first_sample = pd.DataFrame(distances)

# %%
(first_sample[1]/(first_sample[3].apply(lambda x: len(re.sub("odpowiedź: ", "", x)))+first_sample[5].apply(lambda x: len(re.sub("odpowiedź: ", "", x))))).mean()
# Out:
# 0.368589266242476

# %%
(first_sample[0]/(first_sample[3].apply(lambda x: len(re.sub("odpowiedź: ", "", x)))+first_sample[4].apply(lambda x: len(re.sub("odpowiedź: ", "", x))))).mean()
# Out:
# 0.7175559997908675

# %%
impossib_esample = pd.DataFrame(distances)

# %%
(impossib_esample[5] == "odpowiedź: [BRAK_ODPOWIEDZI]").mean()
# Out:
# 0.38

# %%
gen_str
# Out:
# ['odpowiedź: niesprawne systemy strzeleckie, pojazdy opancerzone']

# %%
valid_input
# Out:
#                                              input_text  \
# 0     kontekst: Miszna  Pisma rabiniczne – w tym Mis...
# 1     kontekst: Miszna  Pisma rabiniczne – w tym Mis...
# 2     kontekst: Miszna  Pisma rabiniczne – w tym Mis...
# 3     kontekst: Miszna  Pisma rabiniczne – w tym Mis...
# 4     kontekst: Miszna  Pisma rabiniczne – w tym Mis...
# ...                                                 ...
# 7055  kontekst: Bundeswehra  Reforma sił zbrojnych N...
# 7056  kontekst: Bundeswehra  Reforma sił zbrojnych N...
# 7057  kontekst: Bundeswehra  Reforma sił zbrojnych N...
# 7058  kontekst: Bundeswehra  Reforma sił zbrojnych N...
# 7059  kontekst: Bundeswehra  Reforma sił zbrojnych N...
#
#                                             target_text
# 0     odpowiedź: kompilację poglądów różnych rabinów...
# 1                                      odpowiedź: dwóch
# 2     odpowiedź: pisanej, a drugą część w formie ustnej
# 3                                      odpowiedź: ustna
# 4                          odpowiedź: [BRAK_ODPOWIEDZI]
# ...                                                 ...
# 7055  odpowiedź: 185 tys. żołnierzy i 40 tys. rezerw...
# 7056  odpowiedź: istnieje jednak stały problem z doj...
# 7057      odpowiedź: przewlekłych problemów ze sprzętem
# 7058                       odpowiedź: [BRAK_ODPOWIEDZI]
# 7059  odpowiedź: Sytuacja była tak tragiczna, iż uzn...
#
# [7060 rows x 2 columns]

# %%
train_input.iloc[:20]
# Out:
#                                            input_text  \
# 0   kontekst: Konfederacja polsko-czechosłowacka  ...
# 1   kontekst: Konfederacja polsko-czechosłowacka  ...
# 2   kontekst: Konfederacja polsko-czechosłowacka  ...
# 3   kontekst: Konfederacja polsko-czechosłowacka  ...
# 4   kontekst: Konfederacja polsko-czechosłowacka  ...
# 5   kontekst: Pomilio PD/PE  Samoloty Pomilio PD w...
# 6   kontekst: Pomilio PD/PE  Samoloty Pomilio PD w...
# 7   kontekst: Pomilio PD/PE  Samoloty Pomilio PD w...
# 8   kontekst: Pomilio PD/PE  Samoloty Pomilio PD w...
# 9   kontekst: Pomilio PD/PE  Samoloty Pomilio PD w...
# 10  kontekst: Pomilio PD/PE  Na początku 1918 roku...
# 11  kontekst: Pomilio PD/PE  Na początku 1918 roku...
# 12  kontekst: Pomilio PD/PE  Na początku 1918 roku...
# 13  kontekst: Pomilio PD/PE  Na początku 1918 roku...
# 14  kontekst: Pomilio PD/PE  Na początku 1918 roku...
# 15  kontekst: Edmund Kowal  Kowal trafił do wojska...
# 16  kontekst: Edmund Kowal  Kowal trafił do wojska...
# 17  kontekst: Edmund Kowal  Kowal trafił do wojska...
# 18  kontekst: Edmund Kowal  Kowal trafił do wojska...
# 19  kontekst: Edmund Kowal  Kowal trafił do wojska...
#
#                                           target_text
# 0          odpowiedź: wymianą listów Ripka – Stroński
# 1   odpowiedź: E. Beneša i J. Masaryka z jednej a ...
# 2       odpowiedź: podpisanie układu konfederacyjnego
# 3                                 odpowiedź: E. Beneš
# 4                        odpowiedź: 20 listopada 1942
# 5                               odpowiedź: Pomilio PD
# 6   odpowiedź: dwóch sekcji początkowo przydzielon...
# 7                        odpowiedź: [BRAK_ODPOWIEDZI]
# 8                                       odpowiedź: PE
# 9                        odpowiedź: [BRAK_ODPOWIEDZI]
# 10  odpowiedź: wyposażeniem tylko armijnych eskadr...
# 11                           odpowiedź: Ansaldo SIA 7
# 12                       odpowiedź: słabą konstrukcję
# 13                       odpowiedź: [BRAK_ODPOWIEDZI]
# 14  odpowiedź: zrzucania zaopatrzenia dla żołnierz...
# 15                                    odpowiedź: 1953
# 16                           odpowiedź: jesienią 1952
# 17               odpowiedź: Ministra Obrony Narodowej
# 18  odpowiedź: Uznano, że prawo do reprezentowania...
# 19                       odpowiedź: [BRAK_ODPOWIEDZI]

# %%
sum([dist[0] > dist[1] for dist in distances])/len(distances)
# Out:
# 0.91

# %%
sample["input_text"].iloc[i]
# Out:
# 'kontekst: Konfederacja polsko-czechosłowacka  Projekty konfederacji zaczęły się załamywać 5 sierpnia 1942. Ponownie wróciła kwestia monachijska, co uaktywniło się wymianą listów Ripka – Stroński. Natomiast 17 sierpnia 1942 doszło do spotkania E. Beneša i J. Masaryka z jednej a Wł. Sikorskiego i E. Raczyńskiego z drugiej strony. Polscy dyplomaci zaproponowali podpisanie układu konfederacyjnego. W następnym miesiącu, tj. 24 września, strona polska przesłała na ręce J. Masaryka projekt deklaracji o przyszłej konfederacji obu państw. Strona czechosłowacka projekt przyjęła, lecz już w listopadzie 1942 E. Beneš podważył ideę konfederacji. W zamian zaproponowano zawarcie układu sojuszniczego z Polską na 20 lat (formalnie nastąpiło to 20 listopada 1942).  pytanie: Co było powodem powrócenia konceptu porozumieniu monachijskiego?'

# %%
gen_og_str
# Out:
# ['規.̋.誰.嗨氀愀 [z: ciekawostka:']

# %%
gen_str
# Out:
# ['規.̋.誰.嗨氀愀 [z: ciekawostka:']

# %%
tokenizer_og.batch_decode(gen_og, skip_special_tokens=False)
# Out:
# ['<pad> 規.̋.誰.嗨氀愀 [z: ciekawostka:</s>']
